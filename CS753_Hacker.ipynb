# %% [markdown]
# # Voice Separation with an Unknown Number of Multiple Speakers
# Team Tenacious Tomatoes

# %% [markdown]
# ## Cloning Github from official implementation

# %%
# !git clone https://github.com/facebookresearch/svoice.git
# Out:
# Cloning into 'svoice'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 2.69 MiB | 9.25 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# %cd svoice
# Out:
# /content/svoice

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |████████████████████████████████| 708.0 MB 10 kB/s
# ...
#      |████████████████████████████████| 5.9 MB 28.3 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0+cu113
#     Uninstalling torch-1.11.0+cu113:
#       Successfully uninstalled torch-1.11.0+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.12.0+cu113
#     Uninstalling torchvision-0.12.0+cu113:
#       Successfully uninstalled torchvision-0.12.0+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.6.0+cu101 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.6.0+cu101 which is incompatible.
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 14.5 MB 5.8 MB/s
# ...
#      |████████████████████████████████| 70 kB 9.5 MB/s
# ...
#      |████████████████████████████████| 122 kB 67.8 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 25.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 49.9 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 13.0 MB/s
# ...
#      |████████████████████████████████| 74 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 112 kB 73.1 MB/s
# ...
#      |████████████████████████████████| 20.2 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 56.1 MB/s
# ...
#   Created wheel for pesq: filename=pesq-0.0.2-cp37-cp37m-linux_x86_64.whl size=161294 sha256=4af433649e2cf3b0ea17c09a9bf9e00f7c6aad942b84c2c41fc5b9c9771f16ce
#   Stored in directory: /root/.cache/pip/wheels/c3/34/04/86b0c6c0d3bf5d547542ce1171dfe9e801d65a81c2eb02fe8c
# ...

# %%
# !./make_debug.sh
# Out:
# ...
# 100%|████████████████████████████████████████████| 8/8 [00:00<00:00, 665.84it/s]

# %%
# !pip install --upgrade numpy
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 4.3 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.4
#     Uninstalling numpy-1.19.4:
#       Successfully uninstalled numpy-1.19.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.6.0+cu101 which is incompatible.
# kapre 0.3.7 requires librosa>=0.7.2, but you have librosa 0.7.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %% [markdown]
# ##Train on a small sample of dataset (8 samples)

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/hydra/core/utils.py:143: UserWarning: register_resolver() is deprecated.
# See https://github.com/omry/omegaconf/issues/426 for migration instructions.
#
#   OmegaConf.register_resolver(name, f)
# [2022-05-07 01:30:08,106][__main__][INFO] - For logs, checkpoints and samples check /content/svoice/outputs/exp_
# [2022-05-07 01:30:09,927][__main__][INFO] - Running on host 971c45c9158e
# [2022-05-07 01:30:12,414][svoice.solver][INFO] - ----------------------------------------------------------------------
# [2022-05-07 01:30:12,414][svoice.solver][INFO] - Training...
# [W TensorIterator.cpp:918] Warning: Mixed memory format inputs detected while calling the operator. The operator will output contiguous tensor even if some of the inputs are in channels_last format. (function operator())
# [2022-05-07 01:30:13,861][svoice.solver][INFO] - Train | Epoch 1 | 1/8 | 1.5 it/sec | Loss 21.73007
# ...

# %% [markdown]
# ## Download a new dataset for testing

# %%
# !gdown --folder https://drive.google.com/drive/folders/1hdKdd1SZEK7z0IT2KDo3jCTsbzHVXvIY?usp=sharing
# Out:
# Retrieving folder list
# Retrieving folder 1i5gUvKaei7LMQPTpe4XV1_Tz7hvFeWqD mix
# Processing file 1hh5oGlRp4cf--cTOUo5jfXFJCtD5STwy Example_1_mix.wav
# Retrieving folder 1i5xIr7CTYvpL1cTONgm9tiX4DYorszDz s1
# Processing file 1htazjdkaniT_2FBR_Xa4GvWgSlajd_X0 Example_1_src0.wav
# Retrieving folder 1i84-S9x28DSuLORr6965H4Lwxt2fGTM6 s2
# Processing file 1htgP9bgmeUQQeOllco5ECcvbdjqHIKB4 Example_1_src1.wav
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1hh5oGlRp4cf--cTOUo5jfXFJCtD5STwy
# To: /content/svoice/New_data/mix/Example_1_mix.wav
# 100% 266k/266k [00:00<00:00, 137MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1htazjdkaniT_2FBR_Xa4GvWgSlajd_X0
# To: /content/svoice/New_data/s1/Example_1_src0.wav
# 100% 266k/266k [00:00<00:00, 114MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1htgP9bgmeUQQeOllco5ECcvbdjqHIKB4
# ...

# %% [markdown]
# ## Test on New dataset

# %% [markdown]
# ###Find separated audio

# %%
# !python -m svoice.separate outputs/exp_/checkpoint.th ../outputs --mix_dir=New_data/mix
# Out:
# 100% 1/1 [00:00<00:00,  2.34it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.53it/s]

# %% [markdown]
# ###Play Mixed

# %%
import IPython
IPython.display.Audio('../outputs/Example_1_mix.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###Play Separated Number-1

# %%
IPython.display.Audio('../outputs/Example_1_mix_s1.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###Play Separated Number-2

# %%
IPython.display.Audio('../outputs/Example_1_mix_s2.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Trying to train with new data

# %%
import shutil

shutil.copyfile('New_data/mix/Example_1_mix.wav', 'dataset/debug/mix/Example_1_mix.wav')
shutil.copyfile('New_data/s1/Example_1_src0.wav', 'dataset/debug/s1/Example_1_mix.wav')
shutil.copyfile('New_data/s2/Example_1_src1.wav', 'dataset/debug/s2/Example_1_mix.wav')
# Out:
# 'dataset/debug/s2/Example_1_mix.wav'

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/hydra/core/utils.py:143: UserWarning: register_resolver() is deprecated.
# See https://github.com/omry/omegaconf/issues/426 for migration instructions.
#
#   OmegaConf.register_resolver(name, f)
# [2022-05-07 02:06:06,238][__main__][INFO] - For logs, checkpoints and samples check /content/svoice/outputs/exp_
# [2022-05-07 02:06:07,347][__main__][INFO] - Running on host 971c45c9158e
# [2022-05-07 02:06:09,713][svoice.solver][INFO] - Loading checkpoint model: checkpoint.th
# [2022-05-07 02:06:09,927][svoice.solver][INFO] - Replaying metrics from previous run
# [2022-05-07 02:06:09,927][svoice.solver][INFO] - Epoch 0: train=10.39660 valid=6.42126 best=6.42126
# [2022-05-07 02:06:09,927][svoice.solver][INFO] - Epoch 1: train=3.02383 valid=2.86742 best=2.86742
# [2022-05-07 02:06:09,927][svoice.solver][INFO] - Epoch 2: train=1.88153 valid=2.01192 best=2.01192
# ...

# %% [markdown]
# Because the result produced by only after training with 8 samples were not good, so we wanted to try out what results will be produced when we test on the same data that was given for training. But the model did not pick up new sample for training. So now we test on the data on which model was trained originally.

# %% [markdown]
# ## Test on train data

# %%
# !python -m svoice.separate outputs/exp_/checkpoint.th ../outputs --mix_dir=dataset/debug/mix
# Out:
# 100% 9/9 [00:00<00:00, 20.46it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 9/9 [00:02<00:00,  3.66it/s]

# %% [markdown]
# ###Play Mixed

# %%
IPython.display.Audio('../outputs/1919-142785-0045_6319-275224-0016.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###Play Separated Number-1

# %%
IPython.display.Audio('../outputs/1919-142785-0045_6319-275224-0016_s1.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ###Play Separated Number-2

# %%
IPython.display.Audio('../outputs/1919-142785-0045_6319-275224-0016_s2.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
